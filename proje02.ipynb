# %% [markdown]
# <a href="https://colab.research.google.com/github/ozgenurkaraagac/hu-bby162-2022/blob/main/proje02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import choice

def seviye():
    print("1.Kolay Seviye(10 can) - 2.Orta Seviye(5 can) - 3.Zor Seviye(3 can) - 0.Çıkış")
    calistir = input("Hangi sayı seçimi yapıcaksınız: ")
seviye()

def kolay():
    secilecek = ['odin', 'hulk', 'groot', 'vision', 'thor', 'ego']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 10
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()

        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 9:
                print("9 hakkınız kaldı")
            if toplamHak == 8:
                print("8 hakkınız kaldı")
            if toplamHak == 7:
                print("7 hakkınız kaldı")
            if toplamHak == 6:
                print("6 hakkınız kaldı")
            if toplamHak == 5:
                print("5 hakkınız kaldı")
            if toplamHak == 4:
                print("4 hakkınız kaldı")
            if toplamHak == 3:
                print("3 hakkınız kaldı")
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break
kolay()

def orta():
    secilecek = ['dormammu', 'deadpool', 'punisher', 'galactus']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 5
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()

        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 4:
                print("4 hakkınız kaldı")
            if toplamHak == 3:
                print("3 hakkınız kaldı")
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break
orta()

def zor():
    secilecek = ['grandmaster', 'daredevil', 'wolverine', 'gladiator']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 3
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()
        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break
zor()

def adamasmaca():
  while True:
    if calistir == "1":
       kolay()
    elif calistir == "2":
       orta()
    elif calistir == "3":
       zor()
    elif calistir == "0":
      print("Program kapatıldı")
      break
    else:
      print("Seçtiğiniz karakter tanımlı değil..!")
adamasmaca()

# %%
from random import choice

def kolay():

    secilecek = ['odin', 'hulk', 'groot', 'vision', 'thor', 'ego']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 10
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()

        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 9:
                print("9 hakkınız kaldı")
            if toplamHak == 8:
                print("8 hakkınız kaldı")
            if toplamHak == 7:
                print("7 hakkınız kaldı")
            if toplamHak == 6:
                print("6 hakkınız kaldı")
            if toplamHak == 5:
                print("5 hakkınız kaldı")
            if toplamHak == 4:
                print("4 hakkınız kaldı")
            if toplamHak == 3:
                print("3 hakkınız kaldı")
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break

kolay()


def orta():
  
    secilecek = ['dormammu', 'deadpool', 'punisher', 'galactus']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 5
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()

        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 4:
                print("4 hakkınız kaldı")
            if toplamHak == 3:
                print("3 hakkınız kaldı")
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break

orta()


def zor():
    
    secilecek = ['grandmaster', 'daredevil', 'wolverine', 'gladiator']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 3
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()
        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break

zor()

def adamasmaca():
  while True:
    print("1.Kolay Seviye(10 can) - 2.Orta Seviye(5 can) - 3.Zor Seviye(3 can) - 0.Çıkış")
    calistir = input("Hangi sayı seçimi yapıcaksınız: ")
    if calistir == "1":
       kolay()
    elif calistir == "2":
       orta()
    elif calistir == "3":
       zor()
    elif calistir == "0":
      print("Program kapatıldı")
      break
    else:
      print("Seçtiğiniz karakter tanımlı değil..!")

adamasmaca()
