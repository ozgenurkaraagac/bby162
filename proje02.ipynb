# %% [markdown]
# <a href="https://colab.research.google.com/github/ozgenurkaraagac/hu-bby162-2022/blob/main/proje02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import choice

def kolay():

    secilecek = ['odin', 'hulk', 'groot', 'vision', 'thor', 'ego']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 10
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()

        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 9:
                print("9 hakkınız kaldı")
            if toplamHak == 8:
                print("8 hakkınız kaldı")
            if toplamHak == 7:
                print("7 hakkınız kaldı")
            if toplamHak == 6:
                print("6 hakkınız kaldı")
            if toplamHak == 5:
                print("5 hakkınız kaldı")
            if toplamHak == 4:
                print("4 hakkınız kaldı")
            if toplamHak == 3:
                print("3 hakkınız kaldı")
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break


def orta():
  
    secilecek = ['dormammu', 'deadpool', 'punisher', 'galactus']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 5
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()

        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 4:
                print("4 hakkınız kaldı")
            if toplamHak == 3:
                print("3 hakkınız kaldı")
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break

def zor():
    
    secilecek = ['grandmaster', 'daredevil', 'wolverine', 'gladiator']
    kelimeler = choice(secilecek)
    gecerliHarfler = 'qwertyuıopğüasdfghjklşizxcvbnmöç'
    toplamHak = 3
    yapilanTahmin = ''

    while len(kelimeler) > 0:
        asilKelime = ""
        hataliTahminSayisi = 0

        for harf in kelimeler:
            if harf in yapilanTahmin:
                asilKelime = asilKelime + harf
            else:
                asilKelime = asilKelime + "_" + " "
        if asilKelime == kelimeler:
            print(asilKelime)
            print("Tebrikler kazandınız")
            break

        print("Marvel karakterini tahmin ediniz:" , asilKelime)
        tahmin = input()

        if tahmin in gecerliHarfler:
            yapilanTahmin = yapilanTahmin + tahmin
        else:
            print("Yanlış karakter girişi, tekrar deneyin")
            tahmin = input()
        if tahmin not in kelimeler:
            toplamHak = toplamHak - 1
            if toplamHak == 2:
                print("2 hakkınız kaldı")
            if toplamHak == 1:
                print("1 hakkınız kaldı")
                print("Son tahmin hakkınız")
            if toplamHak == 0:
                print("Oyun bitti")
                print("Kaybettiniz")
                break

def adamasmaca():
  while True:
    print("1.Kolay Seviye(10 can) - 2.Orta Seviye(5 can) - 3.Zor Seviye(3 can) - 0.Çıkış")
    calistir = input("Hangi sayı seçimi yapıcaksınız: ")
    if calistir == "1":
       kolay()
    elif calistir == "2":
       orta()
    elif calistir == "3":
       zor()
    elif calistir == "0":
      print("Program kapatıldı")
      break
    else:
      print("Seçtiğiniz karakter tanımlı değil..!")
    evet= 'e'
    hayır= 'h'
    calistir = input('Tekrar oynamak ister misiniz? - e/h ')
    if calistir == evet:
      print('Oyun tekrar başlıyor :)')
    elif calistir == hayır:
      print('Güle Güle :(')
      break 

adamasmaca()
# Out:
# 1.Kolay Seviye(10 can) - 2.Orta Seviye(5 can) - 3.Zor Seviye(3 can) - 0.Çıkış
# Hangi sayı seçimi yapıcaksınız: 3
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ _ _ _
# a
# 2 hakkınız kaldı
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ _ _ _
# s
# 1 hakkınız kaldı
# Son tahmin hakkınız
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ _ _ _
# d
# Oyun bitti
# Kaybettiniz
# Tekrar oynamak ister misiniz? - e/h e
# Oyun tekrar başlıyor :)
# 1.Kolay Seviye(10 can) - 2.Orta Seviye(5 can) - 3.Zor Seviye(3 can) - 0.Çıkış
# Hangi sayı seçimi yapıcaksınız: 2
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ _ _
# e
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ e_
# f
# 4 hakkınız kaldı
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ e_
# t
# 3 hakkınız kaldı
# Marvel karakterini tahmin ediniz: _ _ _ _ _ _ e_
# h
# Marvel karakterini tahmin ediniz: _ _ _ _ _ he_
# p
# Marvel karakterini tahmin ediniz: p_ _ _ _ he_
# u
# Marvel karakterini tahmin ediniz: pu_ _ _ he_
# n
# Marvel karakterini tahmin ediniz: pun_ _ he_
# i
# Marvel karakterini tahmin ediniz: puni_ he_
# s
# Marvel karakterini tahmin ediniz: punishe_
# h
# Marvel karakterini tahmin ediniz: punishe_
# r
# punisher
# Tebrikler kazandınız
# Tekrar oynamak ister misiniz? - e/h h
# Güle Güle :(
